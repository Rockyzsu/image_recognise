# %%
import requests
import time

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.103 Safari/537.36',
#         'Cookie': 'JSESSIONID=0000ON6gkKwIYAKEokB6Aw35uSl:1c4sn5qb7',
'Host': 'apply.mcard.boc.cn'
        }

d_headers={
'Accept':'text/html, application/xhtml+xml, */*',
'Accept-Language':'zh-CN',
'User-Agent':'Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.2; Trident/6.0)',
'Accept-Encoding':'gzip, deflate',
'Host':'apply.mcard.boc.cn',
'Cookie':'JSESSIONID=0000gOmLkC8zL71hCyrDXiX58Mn:1c4sn5q14'}

# %%
proxy='101.132.235.98'
def get_proxy(retry=10):
    proxyurl = 'http://{}:8101/dynamicIp/common/getDynamicIp.do'.format(proxy)
    count = 0
    for i in range(retry):
        try:
            r = requests.get(proxyurl, timeout=10)
        except Exception as e:
            print(e)
            count += 1
            print('代理获取失败,重试' + str(count))
            time.sleep(1)

        else:
            js = r.json()
            proxyServer = 'https://{0}:{1}'.format(js.get('ip'), js.get('port'))
            proxies_random = {
                'https': proxyServer
            }
            return proxies_random
        
    return None

# %%
url='https://apply.mcard.boc.cn/apply/verificationCode/get?timestamp=1555895928871'
for i in range(300,1000):
    proxy1=get_proxy()
    try:
        r=requests.get(url,headers=d_headers,proxies=proxy1)
    except Exception as e:
        print(e)
        continue
        
    print(r.status_code)
    with open('{}.jpg'.format(i),'wb') as f:
        f.write(r.content)
#     time.sleep(2)
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# ...
